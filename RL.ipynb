# %%
# Faire des prédictions avec le modèle entraîné
y_pred_nn = model.predict(X_nn).flatten()

# Visualiser les données et la ligne de régression du NN
plt.scatter(X, y, label="Données réelles")
plt.plot(X, y_pred_nn, color='purple', label="Ligne de régression (Réseau de Neurones)")
plt.xlabel("Variable indépendante (X)")
plt.ylabel("Variable dépendante (y)")
plt.title("Régression Linéaire avec Réseau de Neurones Simple")
plt.legend()
plt.grid(True)
plt.show()
